# %% [markdown]
# <a href="https://colab.research.google.com/github/nalawneh/jupyter-notebook/blob/main/Udacity_Session_6_%2C_AWS_AI_with_python.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# https://colab.research.google.com/drive/1_56Y9ftnyetjRxWeMU3gqA4u3IIDHhTN?usp=sharing

# %% [markdown]
# Python for data analysis book: https://github.com/wesm/pydata-book/blob/3rd-edition/ch10.ipynb

# %%
import numpy as np
import pandas as pd

# %%
from pandas import Series, DataFrame

# %% [markdown]
# # Series

# %%
obj = pd.Series([4, 7, -5, 3])
print( obj )
# Out:
# 0    4
# 1    7
# 2   -5
# 3    3
# dtype: int64

# %%
obj
# Out:
# 0    4
# 1    7
# 2   -5
# 3    3
# dtype: int64

# %%
obj[0]
# Out:
# np.int64(4)

# %%
obj.values
# Out:
# array([ 4,  7, -5,  3])

# %%
obj.to_list()
# Out:
# [4, 7, -5, 3]

# %%
obj
# Out:
# 0    4
# 1    7
# 2   -5
# 3    3
# dtype: int64

# %%
print( obj.index )
# Out:
# RangeIndex(start=0, stop=4, step=1)

# %%
obj2 = pd.Series([4, 7, -5, 3], index=["d", "b", "a", "c", ] )
obj2
# Out:
# d    4
# b    7
# a   -5
# c    3
# dtype: int64

# %%
print( obj2.index)
# Out:
# Index(['d', 'b', 'a', 'c'], dtype='object')

# %%
print( obj2["a"] )
# Out:
# -5

# %%
obj2["d"] = 6
obj2
# Out:
# d    6
# b    7
# a   -5
# c    3
# dtype: int64

# %%
obj2[ ["c", "a", "d"] ]
# Out:
# c    3
# a   -5
# d    6
# dtype: int64

# %%
obj2
# Out:
# d    6
# b    7
# a   -5
# c    3
# dtype: int64

# %%
obj2 > 0
# Out:
# d     True
# b     True
# a    False
# c     True
# dtype: bool

# %%
obj2[ obj2 > 0 ]
# Out:
# d    6
# b    7
# c    3
# dtype: int64

# %%
obj2 * 2
# Out:
# d    12
# b    14
# a   -10
# c     6
# dtype: int64

# %%
np.exp(obj2)
# Out:
# d     403.428793
# b    1096.633158
# a       0.006738
# c      20.085537
# dtype: float64

# %%
obj2.pow(2)
# Out:
# d    36
# b    49
# a    25
# c     9
# dtype: int64

# %%
np.power( obj2 , 2)
# Out:
# d    36
# b    49
# a    25
# c     9
# dtype: int64

# %%
print( "b" in obj2.index )
print( "e" in obj2.index )
print()
print( "b" in obj2.values )
print( "e" in obj2.values )
# Out:
# True
# False
#
# False
# False

# %%
sdata = {"Ohio": 35000, "Texas": 71000, "Oregon": 16000, "Utah": 5000}
obj3 = pd.Series(sdata)
obj3
# Out:
# Ohio      35000
# Texas     71000
# Oregon    16000
# Utah       5000
# dtype: int64

# %%
obj3.to_

# %%
obj3.to_dict()
# Out:
# {'Ohio': 35000, 'Texas': 71000, 'Oregon': 16000, 'Utah': 5000}

# %%
obj3.values

# %%
obj3.index

# %%
sdata
# Out:
# {'Ohio': 35000, 'Texas': 71000, 'Oregon': 16000, 'Utah': 5000}

# %%
states = ["California", "Ohio", "Oregon", "Texas"]
obj4 = pd.Series(sdata, index= states )
obj4
# Out:
# California        NaN
# Ohio          35000.0
# Oregon        16000.0
# Texas         71000.0
# dtype: float64

# %%
pd.notna(obj4)
# Out:
# California    False
# Ohio           True
# Oregon         True
# Texas          True
# dtype: bool

# %%
obj4[ obj4.notna() ]
# Out:
# Ohio      35000.0
# Oregon    16000.0
# Texas     71000.0
# dtype: float64

# %%
pd.isna(obj4)
# Out:
# California     True
# Ohio          False
# Oregon        False
# Texas         False
# dtype: bool

# %%
obj4[ obj4.isna() ]
# Out:
# California   NaN
# dtype: float64

# %%
print( obj3 )
print()
print( obj4 )

# %%
obj3 + obj4

# %%
obj4.name = "population"
obj4
# Out:
# California        NaN
# Ohio          35000.0
# Oregon        16000.0
# Texas         71000.0
# Name: population, dtype: float64

# %%
obj4.index.name = "state"
obj4
# Out:
# state
# California        NaN
# Ohio          35000.0
# Oregon        16000.0
# Texas         71000.0
# Name: population, dtype: float64

# %%
obj4.index = ["Bob", "Steve", "Jeff", "Ryan"]
obj4

# %% [markdown]
# # Break

# %% [markdown]
# # DataFrames

# %%
import pandas as pd
import numpy as np

# %%
data = {"state": ["Ohio", "Ohio", "Ohio", "Nevada", "Nevada", "Nevada"],
        "year": [2000, 2001, 2002, 2001, 2002, 2003],
        "pop": [1.5, 1.7, 3.6, 2.4, 2.9, 3.2]
        }
frame = pd.DataFrame(data)

# %%
frame
# Out:
#     state  year  pop
# 0    Ohio  2000  1.5
# 1    Ohio  2001  1.7
# 2    Ohio  2002  3.6
# 3  Nevada  2001  2.4
# 4  Nevada  2002  2.9
# 5  Nevada  2003  3.2

# %%
frame.head(2)
# Out:
#   state  year  pop
# 0  Ohio  2000  1.5
# 1  Ohio  2001  1.7

# %%
frame.tail(2)
# Out:
#     state  year  pop
# 4  Nevada  2002  2.9
# 5  Nevada  2003  3.2

# %%
pd.DataFrame(data, columns=["year", "state"] )
# Out:
#    year   state
# 0  2000    Ohio
# 1  2001    Ohio
# 2  2002    Ohio
# 3  2001  Nevada
# 4  2002  Nevada
# 5  2003  Nevada

# %%
frame2 = pd.DataFrame(data, columns=["year", "state", "pop", "debt"])
frame2
# Out:
#    year   state  pop debt
# 0  2000    Ohio  1.5  NaN
# 1  2001    Ohio  1.7  NaN
# 2  2002    Ohio  3.6  NaN
# 3  2001  Nevada  2.4  NaN
# 4  2002  Nevada  2.9  NaN
# 5  2003  Nevada  3.2  NaN

# %%
print( frame2.columns )
# Out:
# Index(['year', 'state', 'pop', 'debt'], dtype='object')

# %%
frame2["state"]
# Out:
# 0      Ohio
# 1      Ohio
# 2      Ohio
# 3    Nevada
# 4    Nevada
# 5    Nevada
# Name: state, dtype: object

# %%
frame2.state

# %%
print(type( frame2["state"] ))
# Out:
# <class 'pandas.core.series.Series'>

# %%
frame2

# %%
frame2.index

# %%
frame2["pop"][2]

# %%
print( frame2.loc[1])
print()
print( frame2.loc[1,"state"])
print()
print( frame2.iloc[1])
print()
print( frame2.iloc[1 , 1])

# %%
print( frame2.loc[1,:])
print()
print( frame2.iloc[:, 1])

# %%
val = pd.DataFrame([-1.2, -1.5, -1.7], index=["two", "four", "five"])
val.head()

# %%
print( val.loc['two'] )
print()
print( val.iloc[0])

# %%
frame2

# %%
frame2["state"] == "Ohio"

# %%
frame2[ frame2["state"] == "Ohio" ]

# %%
frame2["eastern"] = frame2["state"] == "Ohio"
frame2

# %%
frame2.drop( columns=['eastern'] )

# %%
frame2

# %%
del frame2["eastern"]
print( frame2.columns)

# %%
frame2

# %%
populations = {"Ohio": {2000: 1.5, 2001: 1.7, 2002: 3.6},
               "Nevada": {2001: 2.4, 2002: 2.9}
               }

# %%
frame3 = pd.DataFrame(populations)
frame3

# %%
frame3.dropna()

# %%
frame3.fillna("MISSING")

# %%
frame3.T

# %%
tmp= frame3.T

# %%
tmp

# %%
tmp.loc[2000]

# %%
tmp[2000]

# %%
tmp["2000"]

# %%
tmp.columns

# %%
tmp.index

# %%
populations

# %%
pd.DataFrame(populations, index=[2001, 2002, 2003])

# %%
frame3.index.name = "year"
frame3.columns.name = "state"
frame3

# %%
print( frame3.to_numpy())

# %%
data = pd.DataFrame(np.arange(16).reshape((4, 4)),
                    index=["Ohio", "Colorado", "Utah", "New York"],
                    columns=["one", "two", "three", "four"])
data

# %% [markdown]
# using string indexing gives you the columns

# %%
data["two"]

# %%
data[["three", "one"]]

# %% [markdown]
# using numerical indexing gives you the rows

# %%
data[:2]

# %%
data.head()

# %%
data[ data["three"] > 5 ]

# %%
data < 5

# %%
data[data < 5] = 0
data

# %%
data

# %%
data.loc[["Colorado", "New York"]]

# %%
data.loc["Colorado", ["two", "three"]]

# %%
data

# %%
data.iloc[2]

# %%
data.iloc[2, [3, 0, 1]]

# %%
tmp

# %%
tmp.to_csv("tmp.csv")

# %%
tmp.to_excel("tmp.xlsx")

# %%
tmp.to_

# %%
tmp

# %%
tmp

# %%
tmp.iloc[0].plot()

# %%
tmp.iloc[0].hist()

# %% [markdown]
# # For extra Info follow:
# https://pandas.pydata.org/docs/getting_started/intro_tutorials/index.html

# %% [markdown]
# # Activity
# ### Solve the excercises found here : https://www.w3schools.com/python/pandas/exercise.asp?filename=exercise_series1
